# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI

from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatOpenAI()

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    title = state["title"]

    prompt = f"""Generate a detailed outline for a blog post about topic - {title}."""
    outline =  model.invoke(prompt).content
    state["outline"] = outline
    return state


def create_blog(state: BlogState) -> BlogState:
    title = state["title"]
    outline = state["outline"]
    prompt = f"""Wrtite a detailed blog post about topic - {title} based on the following outline: {outline}."""
    content = model.invoke(prompt).content
    state["content"] = content
    return state

# %%
graph = StateGraph(BlogState)

# %%
graph.add_node("create_outline", create_outline)
graph.add_node("create_blog", create_blog)

graph.add_edge(START, "create_outline")
graph.add_edge("create_outline", "create_blog")
graph.add_edge("create_blog", END)

workflow = graph.compile()

# %%
initial_state = {"title": "Rise of AI in india"}

final_state = workflow.invoke(initial_state)

print(final_state["content"])
# Out:
# Artificial Intelligence, or AI, is a rapidly evolving technology that is revolutionizing industries and changing the way we live and work. The term AI refers to computer systems that are able to perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. AI technologies include machine learning, natural language processing, robotics, and neural networks, among others. In the digital age, AI is becoming increasingly important as organizations look for ways to increase efficiency, improve decision-making, and provide better services to customers.
#
# In recent years, India has emerged as a hub for AI innovation and development. The country is home to a growing number of AI startups that are leveraging AI technologies to solve complex problems and drive innovation in various sectors. Investments in AI research and development are also on the rise, with companies and government agencies partnering to support the growth of the AI ecosystem in India. The government has also taken steps to promote AI adoption through initiatives such as the National AI Portal and the National AI Strategy, which aim to advance India's AI capabilities and competitiveness on the global stage.
#
# The applications of AI in India are vast and varied, with potential benefits in healthcare, finance, agriculture, and more. In healthcare, AI is being used for medical imaging analysis, disease diagnosis, and treatment planning, leading to better outcomes for patients. In finance, AI is helping to detect fraud, personalize banking services, and streamline operations. In agriculture, AI is being applied to crop monitoring, management, and predictive analytics for weather patterns, improving crop yields and farmer livelihoods.
#
# Despite the many opportunities that AI presents, there are also challenges to be addressed. One of the key challenges is the skills gap in the AI workforce, with a shortage of trained professionals in AI-related fields. Ethical considerations in AI development, such as data privacy and bias in algorithms, also need to be carefully navigated. There is also concern about the potential for job displacement as AI automation becomes more widespread. However, with the right policies and investments in place, AI has the potential to drive innovation, economic growth, and job creation in India.
#
# Looking ahead, the future of AI in India looks promising. AI has the potential to transform industries, boost productivity, and create new opportunities for businesses and individuals. As India's digital economy continues to grow, AI will play a crucial role in shaping the country's technological advancement and global competitiveness. Collaboration between government, industry, and academia will be key to advancing AI technology and ensuring that India remains at the forefront of AI innovation.
#
# In conclusion, the rise of AI in India presents exciting opportunities for growth and development across various sectors. Policymakers, businesses, and individuals must embrace AI technology and work together to harness its potential for the benefit of society. While there are challenges to overcome, the benefits of AI in India are vast and the country is well-positioned to lead the way in AI innovation and adoption. With the right strategies and investments in place, India can leverage AI to drive progress and prosperity for years to come.

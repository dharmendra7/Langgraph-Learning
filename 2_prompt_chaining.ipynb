# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI

from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatOpenAI()

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    title = state["title"]

    prompt = f"""Generate a detailed outline for a blog post about topic - {title}."""
    outline =  model.invoke(prompt).content
    state["outline"] = outline
    return state


def create_blog(state: BlogState) -> BlogState:
    title = state["title"]
    outline = state["outline"]
    prompt = f"""Wrtite a detailed blog post about topic - {title} based on the following outline: {outline}."""
    content = model.invoke(prompt).content
    state["content"] = content
    return state

# %%
graph = StateGraph(BlogState)

# %%
graph.add_node("create_outline", create_outline)
graph.add_node("create_blog", create_blog)

graph.add_edge(START, "create_outline")
graph.add_edge("create_outline", "create_blog")
graph.add_edge("create_blog", END)

workflow = graph.compile()

# %%
initial_state = {"title": "Rise of AI in india"}

final_state = workflow.invoke(initial_state)

print(final_state["content"])
# Out:
# Artificial Intelligence (AI) is a transformative technology that has the potential to shape the future of various industries and sectors. In recent years, the rise of AI in India has been particularly noteworthy, with the country emerging as a key player in the global AI landscape. In this blog post, we will delve into the current state of AI in India, its advantages, challenges, and future prospects.
#
# I. Introduction
#
# A. Artificial Intelligence (AI) refers to the simulation of human intelligence in machines that are programmed to think and learn like humans. It involves the use of algorithms and data to enable machines to perform tasks that typically require human intelligence.
#
# B. The rise of AI in India can be attributed to the growing demand for AI technologies in various sectors such as healthcare, finance, retail, and manufacturing. India has also become a hub for AI research and development, with a number of companies and startups leading the charge in this space.
#
# C. In this blog post, we will explore the current state of AI in India, the advantages it brings, the challenges it faces, and the future prospects of AI in the country.
#
# II. The current state of AI in India
#
# A. India has witnessed significant growth in the field of AI in recent years, with a number of companies and startups investing in AI research and development. The country is also home to several AI research institutes and labs that are driving innovation in this space.
#
# B. Key players and companies leading the AI revolution in India include companies like Wipro, Infosys, TCS, and startups like Niki.ai, Haptik, and Locus. These companies are leveraging AI technologies to drive efficiencies and enhance customer experiences in various industries.
#
# C. The Indian government has also taken several initiatives to promote AI development in the country, such as the National AI Portal, which aims to promote AI research and development in India.
#
# III. Advantages of AI in India
#
# A. AI has the potential to improve efficiency in various industries by automating repetitive tasks and processes, thereby allowing employees to focus on more strategic tasks.
#
# B. In the healthcare sector, AI can enhance patient outcomes by providing more accurate diagnosis and treatment options. AI-powered tools can also help healthcare providers streamline their operations and improve patient care.
#
# C. AI is driving innovation and technological advancements in India, with companies leveraging AI technologies to develop new products and services that cater to evolving market demands.
#
# D. The rise of AI in India is also creating new job opportunities in the AI sector, with a growing demand for AI experts and professionals.
#
# IV. Challenges faced by AI in India
#
# A. One of the major challenges faced by AI in India is the lack of a skilled workforce and talent shortage. There is a need for more training and upskilling programs to bridge the talent gap in the AI sector.
#
# B. Data privacy and security concerns are also a key challenge for AI in India, with the need for stringent data protection laws and regulations to safeguard personal information.
#
# C. Ethical implications of AI technology, such as biases in algorithms and decision-making processes, are another challenge that needs to be addressed to ensure the responsible use of AI.
#
# D. Regulatory and policy challenges, such as the lack of clear guidelines and standards for AI development and deployment, pose a hurdle to the growth of AI in India.
#
# V. Future prospects of AI in India
#
# A. The future of AI in India looks promising, with predictions for exponential growth in the coming years. The country is poised to become a global leader in AI research and development, with significant opportunities for AI startups and entrepreneurs.
#
# B. AI startups and entrepreneurs in India have the opportunity to leverage AI technologies to drive innovation and disrupt traditional industries, creating new business models and revenue streams.
#
# C. The potential impact of AI on the Indian economy and society is immense, with AI technologies expected to drive economic growth, create jobs, and transform the way we live and work.
#
# VI. Conclusion
#
# A. In conclusion, the rise of AI in India presents a wealth of opportunities for growth, innovation, and advancements in various sectors. It is essential for stakeholders to stay informed and engaged with the development of AI in India to ensure a bright future for the country.
#
# B. Readers are encouraged to explore the possibilities of AI in India and be part of the AI revolution by staying informed and actively participating in AI-related initiatives.
#
# C. Ultimately, AI has the potential to revolutionize the future of India and play a significant role in shaping the country’s economic and social landscape. By embracing AI technologies and driving innovation in this space, India can position itself as a global leader in the AI industry.
